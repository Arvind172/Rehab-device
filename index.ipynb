# %%
# !pip install vpython

# %%
from vpython import *

scene = canvas(width=800, height=600)

thigh = box(pos=vector(0,0,0), length=3, height=0.4, width=0.4, color=color.blue)
shin = box(pos=vector(0,-3,0), length=3, height=0.4, width=0.4, color=color.green)
foot = box(pos=vector(0,-5.5,0.5), length=1.5, height=0.3, width=0.6, color=color.red)

while True:
    rate(60)
    shin.rotate(angle=0.02, axis=vector(1,0,0), origin=vector(0,-1.5,0))
# Out:
# Exception ignored in: <function standardAttributes.__del__ at 0x0000023F52D00C20>
# Traceback (most recent call last):
#   File "c:\Users\reach\anaconda3\Lib\site-packages\vpython\vpython.py", line 1176, in __del__
#     super(standardAttributes, self).__del__()
#   File "c:\Users\reach\anaconda3\Lib\site-packages\vpython\vpython.py", line 348, in __del__
#     cmd = {"cmd": "delete", "idx": self.idx}
# AttributeError: 'box' object has no attribute 'idx'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 from vpython import *
# ----> 3 sphere()
#
# File c:\Users\reach\anaconda3\Lib\site-packages\vpython\vpython.py:1189, in sphere.__init__(self, **args)
#    1187 args['_default_size'] = vector(2,2,2)
#    1188 args['_objName'] = "sphere"
# -> 1189 super(sphere, self).setup(args)
#    1190 self._sizing = False
#
# ...
